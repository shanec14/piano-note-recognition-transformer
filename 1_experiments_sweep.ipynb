# %%
# %cd /content/drive/MyDrive/DeepLearning/FinalProject
# Out:
# /content/drive/MyDrive/DeepLearning/FinalProject

# %%
! pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 100.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 44.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 103.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
! python sweep.py
# Out:
# Streaming output truncated to the last 5000 lines.
# [Threshold = 0.30] Active F1: 0.3630 | Precision: 0.4745 | Recall: 0.3358
# Epoch 301: Loss=0.0351, Val Active F1=0.3630
# [Threshold = 0.30] Active F1: 0.3661 | Precision: 0.4826 | Recall: 0.3319
# Epoch 302: Loss=0.0351, Val Active F1=0.3661
# [Threshold = 0.30] Active F1: 0.3641 | Precision: 0.4769 | Recall: 0.3310
# Epoch 303: Loss=0.0348, Val Active F1=0.3641
# [Threshold = 0.30] Active F1: 0.3652 | Precision: 0.4688 | Recall: 0.3394
# Epoch 304: Loss=0.0345, Val Active F1=0.3652
# [Threshold = 0.30] Active F1: 0.3601 | Precision: 0.4827 | Recall: 0.3261
# Epoch 305: Loss=0.0344, Val Active F1=0.3601
# [Threshold = 0.30] Active F1: 0.3610 | Precision: 0.4772 | Recall: 0.3277
# Epoch 306: Loss=0.0344, Val Active F1=0.3610
# Early stopping at epoch 306
# Launching: python main.py transformer_26 --hparams temp_hparams.yaml
# ...
